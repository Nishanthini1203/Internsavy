# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
df=pd.read_csv("/content/Batsman_Data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Bat1 Runs BF SR 4s 6s    Opposition   Ground   Start Date  \
# 0           1  DNB    -  -  -  -  -       v India   Nagpur  18 Dec 2009
# 1           2  DNB    -  -  -  -  -       v India  Kolkata  24 Dec 2009
# 2           3  DNB    -  -  -  -  -       v India    Delhi  27 Dec 2009
# 3           4  DNB    -  -  -  -  -  v Bangladesh    Dhaka   4 Jan 2010
# 4           5  DNB    -  -  -  -  -       v India    Dhaka   5 Jan 2010
#
#      Match_ID        Batsman  Player_ID
# 0  ODI # 2933  Oshane Thomas      49619
# 1  ODI # 2935  Oshane Thomas      49619
# 2  ODI # 2936  Oshane Thomas      49619
# 3  ODI # 2937  Oshane Thomas      49619
# 4  ODI # 2938  Oshane Thomas      49619

# %%
df.shape
# Out:
# (11149, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11149 entries, 0 to 11148
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11149 non-null  int64
#  1   Bat1        11149 non-null  object
#  2   Runs        11149 non-null  object
#  3   BF          11149 non-null  object
#  4   SR          11149 non-null  object
#  5   4s          11149 non-null  object
#  6   6s          11149 non-null  object
#  7   Opposition  11149 non-null  object
#  8   Ground      11149 non-null  object
#  9   Start Date  11149 non-null  object
#  10  Match_ID    11149 non-null  object
#  11  Batsman     11149 non-null  object
#  12  Player_ID   11149 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.tail()
# Out:
#        Unnamed: 0  Bat1 Runs  BF     SR 4s 6s  Opposition     Ground  \
# 11144       11145    46   46  61  75.40  6  1   v Ireland   Dehradun
# 11145       11146     3    3   6  50.00  0  0   v Ireland   Dehradun
# 11146       11147     1    1   8  12.50  0  0   v Ireland   Dehradun
# 11147       11148   DNB    -   -      -  -  -  v Scotland  Edinburgh
# 11148       11149  TDNB    -   -      -  -  -   v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# 11144  28 Feb 2019  ODI # 4100  Gulbadin Naib      352048
# 11145   2 Mar 2019  ODI # 4101  Gulbadin Naib      352048
# 11146   8 Mar 2019  ODI # 4108  Gulbadin Naib      352048
# 11147  10 May 2019  ODI # 4131  Gulbadin Naib      352048
# 11148  19 May 2019  ODI # 4139  Gulbadin Naib      352048

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Bat1          0
# Runs          0
# BF            0
# SR            0
# 4s            0
# 6s            0
# Opposition    0
# Ground        0
# Start Date    0
# Match_ID      0
# Batsman       0
# Player_ID     0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0  Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1   DNB    -   -      -  -  -       v India     Nagpur
# 1               2   DNB    -   -      -  -  -       v India    Kolkata
# 2               3   DNB    -   -      -  -  -       v India      Delhi
# 3               4   DNB    -   -      -  -  -  v Bangladesh      Dhaka
# 4               5   DNB    -   -      -  -  -       v India      Dhaka
# ...           ...   ...  ...  ..    ... .. ..           ...        ...
# 11144       11145    46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146     3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147     1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148   DNB    -   -      -  -  -    v Scotland  Edinburgh
# 11148       11149  TDNB    -   -      -  -  -     v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# ...

# %%
plt.figure(figsize=(10,8))
plt.title("Rate")
sns.histplot(x="Player_ID",hue="Ground",data=df)
# Out:
# <Axes: title={'center': 'Rate'}, xlabel='Player_ID', ylabel='Count'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning:
#
# Creating legend with loc="best" can be slow with large amounts of data.

# %%
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
Numerics=LabelEncoder()

# %%
df['Opposition']=Numerics.fit_transform(df['Opposition'])

# %%
df['Ground']=Numerics.fit_transform(df['Ground'])

# %%
df['Start Date']=Numerics.fit_transform(df['Start Date'])

# %%
df['Match_ID']=Numerics.fit_transform(df['Match_ID'])

# %%
df['Batsman']=Numerics.fit_transform(df['Batsman'])

# %%
print(df)
# Out:
#        Unnamed: 0  Bat1 Runs  BF     SR 4s 6s  Opposition  Ground  Start Date  \
# 0               1   DNB    -   -      -  -  -           9      92         492
# 1               2   DNB    -   -      -  -  -           9      78         864
# 2               3   DNB    -   -      -  -  -           9      37        1030
# 3               4   DNB    -   -      -  -  -           4      38        1327
# 4               5   DNB    -   -      -  -  -           9      38        1374
# ...           ...   ...  ...  ..    ... .. ..         ...     ...         ...
# 11144       11145    46   46  61  75.40  6  1          10      36        1082
# 11145       11146     3    3   6  50.00  0  0          10      36         622
# 11146       11147     1    1   8  12.50  0  0          10      36        1553
# 11147       11148   DNB    -   -      -  -  -          16      46          93
# 11148       11149  TDNB    -   -      -  -  -          10       8         583
#
# ...

# %%
df.corr()
# Out:
# <ipython-input-19-2f6f6606aa2c>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#             Unnamed: 0  Opposition    Ground  Start Date  Match_ID   Batsman  \
# Unnamed: 0    1.000000    0.144933 -0.034675   -0.011711  0.100532  0.180051
# Opposition    0.144933    1.000000 -0.028872    0.033275 -0.019847  0.052754
# Ground       -0.034675   -0.028872  1.000000    0.044976  0.013722 -0.041421
# Start Date   -0.011711    0.033275  0.044976    1.000000 -0.013529 -0.001373
# Match_ID      0.100532   -0.019847  0.013722   -0.013529  1.000000 -0.078174
# Batsman       0.180051    0.052754 -0.041421   -0.001373 -0.078174  1.000000
# Player_ID     0.036204   -0.015344  0.009180    0.008844  0.467271 -0.018090
#
#             Player_ID
# Unnamed: 0   0.036204
# Opposition  -0.015344
# Ground       0.009180
# ...

# %%
plt.figure(figsize=(12,8))

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-21-8df7bcac526d>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Bat1', 'Runs', 'BF', 'SR', '4s', '6s', 'Opposition',
#        'Ground', 'Start Date', 'Match_ID', 'Batsman', 'Player_ID'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Bat1          object
# Runs          object
# BF            object
# SR            object
# 4s            object
# 6s            object
# Opposition     int64
# Ground         int64
# Start Date     int64
# Match_ID       int64
# Batsman        int64
# Player_ID      int64
# dtype: object

# %%
X=df.drop(['Runs'],axis=1)

# %%
y=df['Runs']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((7469, 12), (3680, 12))

# %%
X_train.dtypes
# Out:
# Unnamed: 0     int64
# Bat1          object
# BF            object
# SR            object
# 4s            object
# 6s            object
# Opposition     int64
# Ground         int64
# Start Date     int64
# Match_ID       int64
# Batsman        int64
# Player_ID      int64
# dtype: object

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn import preprocessing

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Numerics=LabelEncoder()

# %%
df['Opposition']=Numerics.fit_transform(df['Opposition'])
df['Ground']=Numerics.fit_transform(df['Ground'])
df['Start Date']=Numerics.fit_transform(df['Start Date'])
df['Match_ID']=Numerics.fit_transform(df['Match_ID'])
df['Batsman']=Numerics.fit_transform(df['Batsman'])
df['Runs']=Numerics.fit_transform(df['Runs'])
df['BF']=Numerics.fit_transform(df['BF'])
df['SR']=Numerics.fit_transform(df['SR'])
df['4s']=Numerics.fit_transform(df['4s'])
df['6s']=Numerics.fit_transform(df['6s'])
df['Bat1']=Numerics.fit_transform(df['Bat1'])

# %%
print(df)
# Out:
#        Unnamed: 0  Bat1  Runs   BF    SR  4s  6s  Opposition  Ground  \
# 0               1   319     0    0     0   0   0           9      92
# 1               2   319     0    0     0   0   0           9      78
# 2               3   319     0    0     0   0   0           9      37
# 3               4   319     0    0     0   0   0           4      38
# 4               5   319     0    0     0   0   0           9      38
# ...           ...   ...   ...  ...   ...  ..  ..         ...     ...
# 11144       11145   203   121  121  1409  22   2          10      36
# 11145       11146   167   103  119   969   1   1          10      36
# 11146       11147     2     2  141   330   1   1          10      36
# 11147       11148   319     0    0     0   0   0          16      46
# 11148       11149   320     0    0     0   0   0          10       8
#
#        Start Date  Match_ID  Batsman  Player_ID
# 0             492       759      113      49619
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Bat1  Runs  BF  SR  4s  6s  Opposition  Ground  Start Date  \
# 0           1   319     0   0   0   0   0           9      92         492
# 1           2   319     0   0   0   0   0           9      78         864
# 2           3   319     0   0   0   0   0           9      37        1030
# 3           4   319     0   0   0   0   0           4      38        1327
# 4           5   319     0   0   0   0   0           9      38        1374
#
#    Match_ID  Batsman  Player_ID
# 0       759      113      49619
# 1       761      113      49619
# 2       762      113      49619
# 3       763      113      49619
# 4       764      113      49619

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Bat1', 'Runs', 'BF', 'SR', '4s', '6s', 'Opposition',
#        'Ground', 'Start Date', 'Match_ID', 'Batsman', 'Player_ID'],
#       dtype='object')

# %%
X=df[['Unnamed: 0', 'Bat1', 'Runs', 'BF', 'SR', '4s', '6s', 'Opposition',
       'Ground', 'Start Date', 'Match_ID', 'Batsman', 'Player_ID']]

# %%
y=df['Runs']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
X_train.shape
# Out:
# (7804, 13)

# %%
X_train.dtypes
# Out:
# Unnamed: 0    int64
# Bat1          int64
# Runs          int64
# BF            int64
# SR            int64
# 4s            int64
# 6s            int64
# Opposition    int64
# Ground        int64
# Start Date    int64
# Match_ID      int64
# Batsman       int64
# Player_ID     int64
# dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(random_state=0)
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred=rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Model Accuracy score with 10 decision trees:{0:0.4f}".format(accuracy_score(y_test,y_pred)))
# Out:
# Model Accuracy score with 10 decision trees:0.9118
